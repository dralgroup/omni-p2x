# %%
import sys
sys.path.append('/export/home/xacs0959/software/')
import aitomic as ml

# %%
omni = ml.models.methods(method="OMNI-P2x")

# %%
mol = ml.data.molecule()
mol.read_from_smiles_string("C1=CC=CC=C1")

# %%
omni.predict(molecule=mol,nstates=11)

# %%
mol.view()
# Out:
# <div id="3dmolviewer_17447055367684908"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17447055367684908" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
ml.spectra.plot_uvvis(molecule=mol,                   
                                 normalize=False,
                                  labels=["OMNI-P2x"],
                                  spc=True, band_width_slider=False, shift=False, band_width=0.1, filename="Spectrum.png")
